# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Mall_Customers.csv")
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
x=dataset.iloc[:,[3,4]].values

# %%
import numpy as np
from sklearn.cluster import SpectralClustering
from sklearn.metrics import silhouette_score
# Apply Spectral Clustering
n_clusters = 2
sc = SpectralClustering(n_clusters=8, eigen_solver=None, n_components=None, random_state=None, n_init=10, gamma=1.0, affinity='rbf', n_neighbors=10, eigen_tol='auto')
labels = sc.fit_predict(x)  # Get cluster labels

# Compute Silhouette Score
sil_score = silhouette_score(x, labels)
print(f'Silhouette Score: {sil_score:.3f}')
# Out:
# Silhouette Score: 0.314
# C:\Anaconda3\envs\dineshML\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:411: UserWarning: Exited at iteration 2000 with accuracies
# [1.26420707e-13 4.80375380e-07 5.59414918e-07 7.52079493e-07
#  2.17533624e-06 2.61656192e-06 1.75858752e-06 1.16886390e-06
#  3.56308455e-05]
# not reaching the requested tolerance 2.9802322387695312e-06.
# Use iteration 1888 instead with accuracy
# 2.082650352578704e-06.
#
#   _, diffusion_map = lobpcg(
# C:\Anaconda3\envs\dineshML\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:411: UserWarning: Exited postprocessing with accuracies
# [8.18003138e-15 3.18431191e-07 5.80179335e-07 4.90296258e-07
#  1.98407896e-06 1.97999771e-06 1.23938626e-06 9.39765862e-07
#  1.12117371e-05]
# not reaching the requested tolerance 2.9802322387695312e-06.
#   _, diffusion_map = lobpcg(
# ...

# %%
from sklearn.cluster import SpectralClustering

# %%
supervised=pd.DataFrame(dataset)
supervised['cluster_group']=y_labels
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      cluster_group
# 0                0
# 1                0
# 2                0
# ...

# %%
import seaborn as sns
facet=sns.lmplot(data=supervised,x=supervised.columns[3],y=supervised.columns[4],hue=supervised.columns[5],fit_reg=False,legend=True,legend_out=True)
# Out:
# C:\Anaconda3\envs\dineshML\Lib\site-packages\seaborn\regression.py:598: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
