# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Mall_Customers.csv")
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
x=dataset.iloc[:,[3,4]].values

# %%
from sklearn.cluster import SpectralClustering
clustering = SpectralClustering(n_clusters=10, affinity='rbf')
y_labels = clustering.fit_predict(x)
plt.scatter(x[:, 0], x[:, 1], c=y_labels)
plt.show()
# Out:
# C:\Anaconda3\envs\dineshML\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:411: UserWarning: Exited at iteration 1756 with accuracies
# [1.09687929e-11 1.77341847e-07 4.74381323e-07 4.10043438e-07
#  4.12762472e-07 2.74343887e-07 1.28916433e-06 9.91179651e-07
#  8.32360974e-06 2.78386563e-06 3.44571911e-06]
# not reaching the requested tolerance 2.9802322387695312e-06.
# Use iteration 1745 instead with accuracy
# 8.680055701254926e-07.
#
#   _, diffusion_map = lobpcg(
# C:\Anaconda3\envs\dineshML\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:411: UserWarning: Exited postprocessing with accuracies
# [3.51268219e-14 1.76757566e-07 4.32888530e-07 4.05391899e-07
#  3.60089265e-07 2.73922048e-07 7.67917469e-07 5.63062918e-07
#  1.75414116e-06 3.27509726e-06 1.53778004e-06]
# not reaching the requested tolerance 2.9802322387695312e-06.
#   _, diffusion_map = lobpcg(
# ...

# %%
from sklearn.cluster import SpectralClustering

# %%
clustering = SpectralClustering(n_clusters=2,assign_labels='discretize',random_state=0).fit(x)
# Out:
# C:\Anaconda3\envs\dineshML\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:411: UserWarning: Exited at iteration 446 with accuracies
# [1.77192235e-15 4.26495050e-06 2.74149120e-06]
# not reaching the requested tolerance 2.9802322387695312e-06.
# Use iteration 446 instead with accuracy
# 2.335480566266791e-06.
#
#   _, diffusion_map = lobpcg(
# C:\Anaconda3\envs\dineshML\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:411: UserWarning: Exited postprocessing with accuracies
# [1.48135637e-15 4.26494975e-06 2.74149237e-06]
# not reaching the requested tolerance 2.9802322387695312e-06.
#   _, diffusion_map = lobpcg(

# %%
supervised=pd.DataFrame(dataset)
supervised['cluster_group']=y_labels
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      cluster_group
# 0                0
# 1                0
# 2                0
# ...

# %%
import seaborn as sns
facet=sns.lmplot(data=supervised,x=supervised.columns[3],y=supervised.columns[4],hue=supervised.columns[5],fit_reg=False,legend=True,legend_out=True)
# Out:
# C:\Anaconda3\envs\dineshML\Lib\site-packages\seaborn\regression.py:598: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
